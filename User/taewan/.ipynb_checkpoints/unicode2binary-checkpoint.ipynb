# %%
####Unicode link : https://r12a.github.io/apps/encodings/ ###

def uni2bin(unicode):    
    return bin(int(unicode, 16))

hun = input()

output = open('/Users/Taewan/Desktop/output_bin_4.txt' , 'w')

hun_list = hun.split(" ")
binary_list = []
binary_str = ""
for i in hun_list :
    if(i != ""):
        if(i[-1] == " "):
            binary_list.append(uni2bin(i)[2:])
            binary_list.append(" ")
        else : 
            binary_list.append(uni2bin(i)[2:])
print(binary_list)
for i in binary_list :
    output.write(i + " ")
output.close()

output = open('/Users/Taewan/Desktop/output_uni_4.txt' , 'w') 
for i in binary_list :
    if i != "" and i != " ":
        output.write(('%x' % int(i, 2)) +" ")
        print( ('%x' % int(i, 2)) )
    elif i == " ":
        output.write(" ")
output.close()
# Out:
# eb 82 98 ec a4 91 ec 9d 98 20 ec 86 8c eb a6 ac eb 8a 94 20 eb 8b a4 ec 8b 9c 20 ec b2 ab ec 86 8c eb a6 ac eb a5 bc 20 ec 93 b0 eb 8a 90 eb 8b 88 eb 9d bc 20 e3 85 87 ec 9d 84 20 ec 9e 85 ec 88 a0 ec 86 8c eb a6 ac 20 ec 95 84 eb 9e 98 ec 97 90 20 ec 9d b4 ec 96 b4 20 ec 9e 85 ec 88 a0 20 ea b0 80 eb b2 bc ec 9a b4 20 ec 86 8c eb a6 ac ea b0 80 20 eb 90 98 eb 8a 90 eb 8b 88 eb 9d bc 20 ec b2 ab ec 86 8c eb a6 ac eb a5 bc 20 ed 95 a9 ed 95 98 ec 97 ac 20 ec 93 b8 20 ea b2 83 ec 9d b4 20 ec 95 84 eb 8b 88 eb 9d bc eb a9 b4 20 eb 82 98 eb 9e 80 ed 9e 88 20 ec 93 b4 eb 8b a4 20 eb 81 9d ec 86 8c eb a6 ac eb 8f 84 20 eb a7 88 ec b0 ac ea b0 80 ec a7 80 eb 9d bc 20 e1 86 9e ec 99 80 20 e3 85 a1 ec 99 80 20 e3 85 97 ec 99 80 20 e3 85 9c ec 99 80 20 e3 85 9b ec 99 80 20 e3 85 a0 eb 8a 94 20 ec b2 ab ec 86 8c eb a6 ac 20 ec 95 84 eb 9e 98 20 eb b6 99 ec 97 ac ec 84 9c 20 ec 93 b0 ea b3 a0 20 e3 85 a3 ec 99 80 20 e3 85 8f ec 99 80 20 e3 85 93 ec 99 80 20 e3 85 91 ec 99 80 20 e3 85 95 eb 8a 94
# ...

# %%
# Out:
# eb
# 82
# 98
# eb
# 9d
# bc
# ec
# 9d
# 98
# 20
# eb
# a7
# 90
# ec
# 9d
# b4
# 20
# ec
# a4
# 91
# ea
# b5
# ad
# ea
# b3
# bc
# 20
# eb
# 8b
# ac
# eb
# 9d
# bc
# 20
# ec
# 84
# 9c
# eb
# a1
# 9c
# 20
# ed
# 86
# b5
# ed
# 95
# 98
# ec
# a7
# 80
# 20
# ec
# 95
# 84
# eb
# 8b
# 88
# ed
# 95
# 98
# eb
# 8b
# 88
# 20
# ec
# 9d
# b4
# eb
# 9f
# b0
# 20
# ea
# b9
# 8c
# eb
# 8b
# ad
# ec
# 9c
# bc
# eb
# a1
# 9c
# 20
# ec
# 96
# b4
# eb
# a6
# ac
# ec
# 84
# 9d
# ec
# 9d
# 80
# 20
# eb
# b0
# b1
# ec
# 84
# b1
# eb
# 93
# a4
# ec
# 9d
# b4
# 20
# eb
# a7
# 90
# ed
# 95
# 98
# ea
# b3
# a0
# ec
# 9e
# 90
# 20
# ed
# 95
# 98
# eb
# 8a
# 94
# 20
# eb
# b0
# 94
# ea
# b0
# 80
# 20
# ec
# 9e
# 88
# ec
# 96
# b4
# eb
# 8f
# 84
# 20
# eb
# a7
# 88
# ec
# b9
# a8
# eb
# 82
# b4
# 20
# ec
# a0
# 9c
# 20
# eb
# 9c
# bb
# ec
# 9d
# 84
# 20
# eb
# 8a
# a5
# ed
# 9e
# 88
# 20
# ed
# 8f
# 89
# ec
# a7
# 80
# 20
# eb
# aa
# bb
# ed
# 95
# 98
# eb
# 8a
# 94
# 20
# ec
# 82
# ac
# eb
# 9e
# 8c
# ec
# 9d
# ...
